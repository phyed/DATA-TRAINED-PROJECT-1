# %%
# NECESSARY LIBRARIES IMPORT----
import pandas as pd
import numpy as np

# %% [markdown]
# # EDA

# %%
data=pd.read_csv('student-mat.csv')    # reading the dataset

# %%
data    # viewing the data set
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
data.head()    # viewing first five rows
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# total 33 columns are there

# %%
data.info() # getting the info of data set ---33 columns & 395 rows of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# Now we will see final grade
data['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %% [markdown]
# It gives the statistical summary of column G3

# %% [markdown]
# TOtal number of rows =395

# %%
# we are now trying to understand our dataset using seaborn and matplotlib...

import seaborn as sns
import matplotlib.pyplot as plt
b=sns.countplot(data['G3'])
b.axes.set_title('Distribution of final grade of students',fontsize=25)
b.set_xlabel('Final Grade',fontsize=20)
b.set_ylabel('Count',fontsize=20)
import warnings
warnings.filterwarnings('ignore')

# %%
data.shape
# Out:
# (395, 33)

# %% [markdown]
# .shape() function gives the total row count & column count

# %%
#Now we will check null values ,if there any 
print('---SHOWING INDIVIDUAL NULL VALUES---','\n',data.isnull().sum())
print('-----------------------------------------------------------------------------')
print('---SHOWING TOTAL NULL VALUES---','\n',data.isnull().sum().sum())
print('-----------------------------------------------------------------------------')
print('---Showing in Boolean form---','\n',data.isnull().any())
# Out:
# ---SHOWING INDIVIDUAL NULL VALUES---
#  school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64
# -----------------------------------------------------------------------------
# ---SHOWING TOTAL NULL VALUES---
#  0
# -----------------------------------------------------------------------------
# ---Showing in Boolean form---
#  school        False
# sex           False
# age           False
# address       False
# famsize       False
# ...

# %% [markdown]
# Now we want to see total no. of male students and female students----

# %%
male_students=len(data[data['sex']=='M'])
female_students=len(data[data['sex']=='F'])
print('No. of male students :',male_students)
print('No. of female students :',female_students)
# Out:
# No. of male students : 187
# No. of female students : 208

# %%
# no of students of different age group we will check now
b=sns.countplot('age',hue='sex',data=data)
b.axes.set_title('Number of students in different age groups',fontsize=30)
b.set_xlabel('Age',fontsize=30)
b.set_ylabel('Count',fontsize=30)
# Out:
# Text(0, 0.5, 'Count')

# %%
# checking the count plots of urban & rural students
b=sns.countplot(data['address'])
b.axes.set_title('Urban & rural students',fontsize=30)
b.set_xlabel('Address',fontsize=20)
b.set_ylabel('Count',fontsize=20)
# Out:
# Text(0, 0.5, 'Count')

# %%
# we will check the correlation of data of 'G3'
data.corr()['G3'].sort_values()
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %% [markdown]
# From the data above let's create one more column to get the average from G1 to G3

# %%
data['GradeAvg']=(data['G1']+data['G2']+data['G3'])/3

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'GradeAvg'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
#  One more column 'GradeAvg' is added

# %% [markdown]
# Now let's create a grading based on the 'GradeAvg'
#  (i) above 90 %=Grade A
#  (ii) btw 70% to 90% =Grade B
#  (iii) below 70 % =Grade C
# ------This is mapping of data

# %%
def find_grade(data):
    grades=[]
    for row in data['GradeAvg']:
        if row>= (0.9 * data['GradeAvg'].max()):
            grades.append('1')
        elif row>= (0.7 * data['GradeAvg'].max()):
            grades.append('2')
        elif row< (0.7*data['GradeAvg'].max()):
            grades.append('3')
    data['GradeAvg']=grades
    return data

# %%
data_dum=find_grade(data)

# %%
data_dum
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Now we will drop 'school' & 'age' like cols since they are not computational values

# %%
data_dum.drop(['school','age','address'],axis=1,inplace=True)

# %%
data_dum.head()
# Out:
#   sex famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason guardian  \
# 0   F     GT3       A     4     4  at_home   teacher  course   mother
# 1   F     GT3       T     1     1  at_home     other  course   father
# 2   F     LE3       T     1     1  at_home     other   other   mother
# 3   F     GT3       T     4     2   health  services    home   mother
# 4   F     GT3       T     3     3    other     other    home   father
#
#    traveltime  ...  freetime  goout Dalc Walc health absences  G1  G2  G3  \
# 0           2  ...         3      4    1    1      3        6   5   6   6
# 1           1  ...         3      3    1    1      3        4   5   5   6
# 2           1  ...         3      2    2    3      3       10   7   8  10
# 3           1  ...         2      2    1    1      5        2  15  14  15
# 4           1  ...         3      2    1    2      5        4   6  10  10
#
#   GradeAvg
# 0        3
# 1        3
# 2        3
# 3        2
# 4        3
#
# ...

# %%
data_dum.columns
# Out:
# Index(['sex', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason',
#        'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup',
#        'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
#        'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health',
#        'absences', 'G1', 'G2', 'G3', 'GradeAvg'],
#       dtype='object')

# %% [markdown]
# No 'school' & 'age' ,'address' cols are there

# %% [markdown]
# Now we will encode the dataset means convert the string values into categorical values(mapping of data)

# %%
# map the yes/no data
d={'yes':1,'no':0}
data_dum['schoolsup']=data_dum['schoolsup'].map(d)
data_dum['famsup']=data_dum['famsup'].map(d)
data_dum['paid']=data_dum['paid'].map(d)
data_dum['activities']=data_dum['activities'].map(d)
data_dum['nursery']=data_dum['nursery'].map(d)
data_dum['higher']=data_dum['higher'].map(d)
data_dum['internet']=data_dum['internet'].map(d)

data_dum['romantic']=data_dum['romantic'].map(d)

# %%
# map the 'M' ,'F' data
d={'F':1,'M':0}
data_dum['sex']=data_dum['sex'].map(d)

# %%
# map the parent's job--
d={'teacher':0,'health':1,'services':2,'at_home':3,'other':4}
data_dum['Mjob']=data_dum['Mjob'].map(d)
data_dum['Fjob']=data_dum['Fjob'].map(d)

# %%
# map the reason data

d={'home':0,'reputation':1,'course':2,'other':3}
data_dum['reason']=data_dum['reason'].map(d)

# %%
# map the guardian data
d={'mother':0,'father':1,'other':2}
data_dum['guardian']=data_dum['guardian'].map(d)

# %%
data_dum
# Out:
#      sex famsize Pstatus  Medu  Fedu  Mjob  Fjob  reason  guardian  \
# 0      1     GT3       A     4     4     3     0       2         0
# 1      1     GT3       T     1     1     3     4       2         1
# 2      1     LE3       T     1     1     3     4       3         0
# 3      1     GT3       T     4     2     1     2       0         0
# 4      1     GT3       T     3     3     4     4       0         1
# ..   ...     ...     ...   ...   ...   ...   ...     ...       ...
# 390    0     LE3       A     2     2     2     2       2         2
# 391    0     LE3       T     3     1     2     2       2         0
# 392    0     GT3       T     1     1     4     4       2         2
# 393    0     LE3       T     3     2     2     4       2         0
# 394    0     LE3       T     1     1     4     3       2         1
#
#      traveltime  ...  freetime  goout  Dalc  Walc  health  absences  G1  G2  \
# 0             2  ...         3      4     1     1       3         6   5   6
# ...

# %%
data_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         395 non-null    int64
#  1   famsize     395 non-null    object
#  2   Pstatus     395 non-null    object
#  3   Medu        395 non-null    int64
#  4   Fedu        395 non-null    int64
#  5   Mjob        395 non-null    int64
#  6   Fjob        395 non-null    int64
#  7   reason      395 non-null    int64
#  8   guardian    395 non-null    int64
#  9   traveltime  395 non-null    int64
#  10  studytime   395 non-null    int64
#  11  failures    395 non-null    int64
#  12  schoolsup   395 non-null    int64
#  13  famsup      395 non-null    int64
#  14  paid        395 non-null    int64
#  15  activities  395 non-null    int64
#  16  nursery     395 non-null    int64
#  17  higher      395 non-null    int64
#  18  internet    395 non-null    int64
# ...

# %%
# map the 'Pstatus'
d={'A':0,'T':1}
data_dum['Pstatus']=data_dum['Pstatus'].map(d)

# %%
data_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         395 non-null    int64
#  1   famsize     395 non-null    object
#  2   Pstatus     395 non-null    int64
#  3   Medu        395 non-null    int64
#  4   Fedu        395 non-null    int64
#  5   Mjob        395 non-null    int64
#  6   Fjob        395 non-null    int64
#  7   reason      395 non-null    int64
#  8   guardian    395 non-null    int64
#  9   traveltime  395 non-null    int64
#  10  studytime   395 non-null    int64
#  11  failures    395 non-null    int64
#  12  schoolsup   395 non-null    int64
#  13  famsup      395 non-null    int64
#  14  paid        395 non-null    int64
#  15  activities  395 non-null    int64
#  16  nursery     395 non-null    int64
#  17  higher      395 non-null    int64
#  18  internet    395 non-null    int64
# ...

# %%
# map the 'famsize'
d={'GT3':0,'LE3':1}
data_dum['famsize']=data_dum['famsize'].map(d)

# %%
data_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         395 non-null    int64
#  1   famsize     395 non-null    int64
#  2   Pstatus     395 non-null    int64
#  3   Medu        395 non-null    int64
#  4   Fedu        395 non-null    int64
#  5   Mjob        395 non-null    int64
#  6   Fjob        395 non-null    int64
#  7   reason      395 non-null    int64
#  8   guardian    395 non-null    int64
#  9   traveltime  395 non-null    int64
#  10  studytime   395 non-null    int64
#  11  failures    395 non-null    int64
#  12  schoolsup   395 non-null    int64
#  13  famsup      395 non-null    int64
#  14  paid        395 non-null    int64
#  15  activities  395 non-null    int64
#  16  nursery     395 non-null    int64
#  17  higher      395 non-null    int64
#  18  internet    395 non-null    int64
# ...

# %% [markdown]
# Now we will do Modeling----

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x=data_dum.drop('G3',axis=1)
y=data_dum['G3']

# %%
x
# Out:
#      sex  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  guardian  \
# 0      1        0        0     4     4     3     0       2         0
# 1      1        0        1     1     1     3     4       2         1
# 2      1        1        1     1     1     3     4       3         0
# 3      1        0        1     4     2     1     2       0         0
# 4      1        0        1     3     3     4     4       0         1
# ..   ...      ...      ...   ...   ...   ...   ...     ...       ...
# 390    0        1        0     2     2     2     2       2         2
# 391    0        1        1     3     1     2     2       2         0
# 392    0        0        1     1     1     4     4       2         2
# 393    0        1        1     3     2     2     4       2         0
# 394    0        1        1     1     1     4     3       2         1
#
#      traveltime  ...  famrel  freetime  goout  Dalc  Walc  health  absences  \
# ...

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: G3, Length: 395, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
L=LinearRegression()
L.fit(x_train,y_train)
y_pred=L.predict(x_test)
print(L.score(x_test,y_test))
# Out:
# 0.7784849903951065

# %%
The accuracy is 77 %
